# %%
# !pip install astropy
# Out:
# Requirement already satisfied: astropy in /opt/conda/lib/python3.11/site-packages (7.0.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from astropy) (1.24.4)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /opt/conda/lib/python3.11/site-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2024.10.28.0.34.7 in /opt/conda/lib/python3.11/site-packages (from astropy) (0.2024.11.25.0.34.48)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/conda/lib/python3.11/site-packages (from astropy) (6.0.1)
# Requirement already satisfied: packaging>=22.0.0 in /opt/conda/lib/python3.11/site-packages (from astropy) (23.2)

# %%
# !pip install dblinea
# Out:
# Requirement already satisfied: dblinea in /opt/conda/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: sqlalchemy>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from dblinea) (2.0.22)
# Requirement already satisfied: psycopg2-binary>=2.9.1 in /opt/conda/lib/python3.11/site-packages (from dblinea) (2.9.10)
# Requirement already satisfied: numpy>=1.19.4 in /opt/conda/lib/python3.11/site-packages (from dblinea) (1.24.4)
# Requirement already satisfied: pandas>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from dblinea) (2.1.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.11/site-packages (from dblinea) (2.31.0)
# Requirement already satisfied: astropy>=5.0.0 in /opt/conda/lib/python3.11/site-packages (from dblinea) (7.0.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /opt/conda/lib/python3.11/site-packages (from astropy>=5.0.0->dblinea) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2024.10.28.0.34.7 in /opt/conda/lib/python3.11/site-packages (from astropy>=5.0.0->dblinea) (0.2024.11.25.0.34.48)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/conda/lib/python3.11/site-packages (from astropy>=5.0.0->dblinea) (6.0.1)
# Requirement already satisfied: packaging>=22.0.0 in /opt/conda/lib/python3.11/site-packages (from astropy>=5.0.0->dblinea) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.0.0->dblinea) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.0.0->dblinea) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.0.0->dblinea) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->dblinea) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->dblinea) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->dblinea) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->dblinea) (2023.7.22)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy>=2.0.0->dblinea) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy>=2.0.0->dblinea) (3.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->dblinea) (1.16.0)

# %%
import matplotlib.pyplot as plt
import pandas as pd
from astropy import units as u
from astropy.coordinates import SkyCoord

from dblinea import DBBase

# %reload_ext autoreload
# %autoreload 2

# %%
db = DBBase()

# %%
schema = "des_dr2"
tablename = "main"

# %%
db.get_table_columns(tablename, schema=schema)
# Out:
# ['coadd_object_id',
#  'tilename',
#  'hpix_32',
#  'hpix_64',
#  'hpix_1024',
#  'hpix_4096',
#  'hpix_16384',
#  'ra',
#  'dec',
#  'alphawin_j2000',
#  'deltawin_j2000',
#  'galactic_l',
#  'galactic_b',
#  'xwin_image',
#  'ywin_image',
#  'a_image',
#  'erra_image',
#  'b_image',
#  'errb_image',
#  'theta_j2000',
#  'errtheta_image',
#  'kron_radius',
#  'ebv_sfd98',
#  'mag_auto_g_dered',
#  'mag_auto_r_dered',
#  'mag_auto_i_dered',
#  'mag_auto_z_dered',
#  'mag_auto_y_dered',
#  'wavg_mag_psf_g_dered',
#  'wavg_mag_psf_r_dered',
#  'wavg_mag_psf_i_dered',
#  'wavg_mag_psf_z_dered',
#  'wavg_mag_psf_y_dered',
#  'extended_class_coadd',
#  'extended_class_wavg',
#  'flags_g',
#  'imaflags_iso_g',
#  'nepochs_g',
#  'flags_r',
#  'imaflags_iso_r',
#  'nepochs_r',
#  'flags_i',
#  'imaflags_iso_i',
#  'nepochs_i',
#  'flags_z',
#  'imaflags_iso_z',
#  'nepochs_z',
#  'flags_y',
#  'imaflags_iso_y',
#  'nepochs_y',
#  'xwin_image_g',
#  'xwin_image_r',
#  'xwin_image_i',
#  'xwin_image_z',
#  'xwin_image_y',
#  'ywin_image_g',
#  'ywin_image_r',
#  'ywin_image_i',
#  'ywin_image_z',
#  'ywin_image_y',
#  'x2win_image_g',
#  'x2win_image_r',
#  'x2win_image_i',
#  'x2win_image_z',
#  'x2win_image_y',
#  'y2win_image_g',
#  'y2win_image_r',
#  'y2win_image_i',
#  'y2win_image_z',
#  'y2win_image_y',
#  'xywin_image_g',
#  'xywin_image_r',
#  'xywin_image_i',
#  'xywin_image_z',
#  'xywin_image_y',
#  'errx2win_image_g',
#  'errx2win_image_r',
#  'errx2win_image_i',
#  'errx2win_image_z',
#  'errx2win_image_y',
#  'erry2win_image_g',
#  'erry2win_image_r',
#  'erry2win_image_i',
#  'erry2win_image_z',
#  'erry2win_image_y',
#  'errxywin_image_g',
#  'errxywin_image_r',
#  'errxywin_image_i',
#  'errxywin_image_z',
#  'errxywin_image_y',
#  'awin_image_g',
#  'awin_image_r',
#  'awin_image_i',
#  'awin_image_z',
#  'awin_image_y',
#  'bwin_image_g',
#  'bwin_image_r',
#  'bwin_image_i',
#  'bwin_image_z',
#  'bwin_image_y',
#  'thetawin_image_g',
#  'thetawin_image_r',
#  'thetawin_image_i',
#  'thetawin_image_z',
#  'thetawin_image_y',
#  'errawin_image_g',
#  'errawin_image_r',
#  'errawin_image_i',
#  'errawin_image_z',
#  'errawin_image_y',
#  'errbwin_image_g',
#  'errbwin_image_r',
#  'errbwin_image_i',
#  'errbwin_image_z',
#  'errbwin_image_y',
#  'errthetawin_image_g',
#  'errthetawin_image_r',
#  'errthetawin_image_i',
#  'errthetawin_image_z',
#  'errthetawin_image_y',
#  'flux_radius_g',
#  'flux_radius_r',
#  'flux_radius_i',
#  'flux_radius_z',
#  'flux_radius_y',
#  'fwhm_image_g',
#  'fwhm_image_r',
#  'fwhm_image_i',
#  'fwhm_image_z',
#  'fwhm_image_y',
#  'isoarea_image_g',
#  'isoarea_image_r',
#  'isoarea_image_i',
#  'isoarea_image_z',
#  'isoarea_image_y',
#  'background_g',
#  'background_r',
#  'background_i',
#  'background_z',
#  'background_y',
#  'niter_model_g',
#  'niter_model_r',
#  'niter_model_i',
#  'niter_model_z',
#  'niter_model_y',
#  'kron_radius_g',
#  'kron_radius_r',
#  'kron_radius_i',
#  'kron_radius_z',
#  'kron_radius_y',
#  'mag_auto_g',
#  'mag_auto_r',
#  'mag_auto_i',
#  'mag_auto_z',
#  'mag_auto_y',
#  'magerr_auto_g',
#  'magerr_auto_r',
#  'magerr_auto_i',
#  'magerr_auto_z',
#  'magerr_auto_y',
#  'wavg_mag_psf_g',
#  'wavg_mag_psf_r',
#  'wavg_mag_psf_i',
#  'wavg_mag_psf_z',
#  'wavg_mag_psf_y',
#  'wavg_magerr_psf_g',
#  'wavg_magerr_psf_r',
#  'wavg_magerr_psf_i',
#  'wavg_magerr_psf_z',
#  'wavg_magerr_psf_y',
#  'flux_auto_g',
#  'flux_auto_r',
#  'flux_auto_i',
#  'flux_auto_z',
#  'flux_auto_y',
#  'fluxerr_auto_g',
#  'fluxerr_auto_r',
#  'fluxerr_auto_i',
#  'fluxerr_auto_z',
#  'fluxerr_auto_y',
#  'wavg_flux_psf_g',
#  'wavg_flux_psf_r',
#  'wavg_flux_psf_i',
#  'wavg_flux_psf_z',
#  'wavg_flux_psf_y',
#  'wavg_fluxerr_psf_g',
#  'wavg_fluxerr_psf_r',
#  'wavg_fluxerr_psf_i',
#  'wavg_fluxerr_psf_z',
#  'wavg_fluxerr_psf_y',
#  'class_star_g',
#  'class_star_r',
#  'class_star_i',
#  'class_star_z',
#  'class_star_y',
#  'spread_model_g',
#  'spread_model_r',
#  'spread_model_i',
#  'spread_model_z',
#  'spread_model_y',
#  'wavg_spread_model_g',
#  'wavg_spread_model_r',
#  'wavg_spread_model_i',
#  'wavg_spread_model_z',
#  'wavg_spread_model_y',
#  'spreaderr_model_g',
#  'spreaderr_model_r',
#  'spreaderr_model_i',
#  'spreaderr_model_z',
#  'spreaderr_model_y',
#  'wavg_spreaderr_model_g',
#  'wavg_spreaderr_model_r',
#  'wavg_spreaderr_model_i',
#  'wavg_spreaderr_model_z',
#  'wavg_spreaderr_model_y']

# %%
db.describe_table(tablename, schema=schema)
# Out:
# [{'name': 'coadd_object_id', 'type': BIGINT()},
#  {'name': 'tilename', 'type': TEXT()},
#  {'name': 'hpix_32', 'type': BIGINT()},
#  {'name': 'hpix_64', 'type': BIGINT()},
#  {'name': 'hpix_1024', 'type': BIGINT()},
#  {'name': 'hpix_4096', 'type': BIGINT()},
#  {'name': 'hpix_16384', 'type': BIGINT()},
#  {'name': 'ra', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'dec', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'alphawin_j2000', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'deltawin_j2000', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'galactic_l', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'galactic_b', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'xwin_image', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'ywin_image', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'a_image', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'erra_image', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'b_image', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errb_image', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'theta_j2000', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errtheta_image', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'kron_radius', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'ebv_sfd98', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'mag_auto_g_dered', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'mag_auto_r_dered', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'mag_auto_i_dered', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'mag_auto_z_dered', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'mag_auto_y_dered', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_mag_psf_g_dered', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_mag_psf_r_dered', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_mag_psf_i_dered', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_mag_psf_z_dered', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_mag_psf_y_dered', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'extended_class_coadd', 'type': INTEGER()},
#  {'name': 'extended_class_wavg', 'type': INTEGER()},
#  {'name': 'flags_g', 'type': INTEGER()},
#  {'name': 'imaflags_iso_g', 'type': INTEGER()},
#  {'name': 'nepochs_g', 'type': INTEGER()},
#  {'name': 'flags_r', 'type': INTEGER()},
#  {'name': 'imaflags_iso_r', 'type': INTEGER()},
#  {'name': 'nepochs_r', 'type': INTEGER()},
#  {'name': 'flags_i', 'type': INTEGER()},
#  {'name': 'imaflags_iso_i', 'type': INTEGER()},
#  {'name': 'nepochs_i', 'type': INTEGER()},
#  {'name': 'flags_z', 'type': INTEGER()},
#  {'name': 'imaflags_iso_z', 'type': INTEGER()},
#  {'name': 'nepochs_z', 'type': INTEGER()},
#  {'name': 'flags_y', 'type': INTEGER()},
#  {'name': 'imaflags_iso_y', 'type': INTEGER()},
#  {'name': 'nepochs_y', 'type': INTEGER()},
#  {'name': 'xwin_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'xwin_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'xwin_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'xwin_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'xwin_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'ywin_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'ywin_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'ywin_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'ywin_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'ywin_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'x2win_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'x2win_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'x2win_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'x2win_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'x2win_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'y2win_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'y2win_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'y2win_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'y2win_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'y2win_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'xywin_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'xywin_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'xywin_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'xywin_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'xywin_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errx2win_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errx2win_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errx2win_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errx2win_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errx2win_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'erry2win_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'erry2win_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'erry2win_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'erry2win_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'erry2win_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errxywin_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errxywin_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errxywin_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errxywin_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errxywin_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'awin_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'awin_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'awin_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'awin_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'awin_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'bwin_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'bwin_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'bwin_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'bwin_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'bwin_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'thetawin_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'thetawin_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'thetawin_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'thetawin_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'thetawin_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errawin_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errawin_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errawin_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errawin_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errawin_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errbwin_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errbwin_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errbwin_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errbwin_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errbwin_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errthetawin_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errthetawin_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errthetawin_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errthetawin_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'errthetawin_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'flux_radius_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'flux_radius_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'flux_radius_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'flux_radius_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'flux_radius_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'fwhm_image_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'fwhm_image_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'fwhm_image_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'fwhm_image_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'fwhm_image_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'isoarea_image_g', 'type': INTEGER()},
#  {'name': 'isoarea_image_r', 'type': INTEGER()},
#  {'name': 'isoarea_image_i', 'type': INTEGER()},
#  {'name': 'isoarea_image_z', 'type': INTEGER()},
#  {'name': 'isoarea_image_y', 'type': INTEGER()},
#  {'name': 'background_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'background_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'background_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'background_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'background_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'niter_model_g', 'type': INTEGER()},
#  {'name': 'niter_model_r', 'type': INTEGER()},
#  {'name': 'niter_model_i', 'type': INTEGER()},
#  {'name': 'niter_model_z', 'type': INTEGER()},
#  {'name': 'niter_model_y', 'type': INTEGER()},
#  {'name': 'kron_radius_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'kron_radius_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'kron_radius_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'kron_radius_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'kron_radius_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'mag_auto_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'mag_auto_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'mag_auto_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'mag_auto_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'mag_auto_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'magerr_auto_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'magerr_auto_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'magerr_auto_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'magerr_auto_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'magerr_auto_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_mag_psf_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_mag_psf_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_mag_psf_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_mag_psf_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_mag_psf_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_magerr_psf_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_magerr_psf_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_magerr_psf_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_magerr_psf_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_magerr_psf_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'flux_auto_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'flux_auto_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'flux_auto_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'flux_auto_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'flux_auto_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'fluxerr_auto_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'fluxerr_auto_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'fluxerr_auto_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'fluxerr_auto_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'fluxerr_auto_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_flux_psf_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_flux_psf_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_flux_psf_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_flux_psf_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_flux_psf_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_fluxerr_psf_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_fluxerr_psf_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_fluxerr_psf_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_fluxerr_psf_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_fluxerr_psf_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'class_star_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'class_star_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'class_star_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'class_star_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'class_star_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'spread_model_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'spread_model_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'spread_model_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'spread_model_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'spread_model_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_spread_model_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_spread_model_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_spread_model_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_spread_model_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_spread_model_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'spreaderr_model_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'spreaderr_model_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'spreaderr_model_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'spreaderr_model_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'spreaderr_model_y', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_spreaderr_model_g', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_spreaderr_model_r', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_spreaderr_model_i', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_spreaderr_model_z', 'type': DOUBLE_PRECISION(precision=53)},
#  {'name': 'wavg_spreaderr_model_y', 'type': DOUBLE_PRECISION(precision=53)}]

# %%
query = "SELECT coadd_object_id, ra, dec FROM des_dr2.main limit 10"
Lista_10_objetos = db.fetchall(query)
Lista_10_objetos
# Out:
# [(1529220421, 76.914089, -46.937152),
#  (1529220121, 76.918024, -46.934654),
#  (1529220129, 76.914734, -46.934679),
#  (1529220385, 76.912989, -46.936798),
#  (1529220066, 76.911689, -46.934485),
#  (1529220084, 76.923009, -46.934203),
#  (1529220030, 76.923706, -46.933679),
#  (1529219643, 76.925857, -46.930103),
#  (1529219488, 76.928655, -46.928536),
#  (1529219566, 76.923838, -46.929452)]

# %%
dict_10_objetos = db.fetchall_dict(query)
dict_10_objetos
# Out:
# [{'coadd_object_id': 1529220421, 'ra': 76.914089, 'dec': -46.937152},
#  {'coadd_object_id': 1529220121, 'ra': 76.918024, 'dec': -46.934654},
#  {'coadd_object_id': 1529220129, 'ra': 76.914734, 'dec': -46.934679},
#  {'coadd_object_id': 1529220385, 'ra': 76.912989, 'dec': -46.936798},
#  {'coadd_object_id': 1529220066, 'ra': 76.911689, 'dec': -46.934485},
#  {'coadd_object_id': 1529220084, 'ra': 76.923009, 'dec': -46.934203},
#  {'coadd_object_id': 1529220030, 'ra': 76.923706, 'dec': -46.933679},
#  {'coadd_object_id': 1529219643, 'ra': 76.925857, 'dec': -46.930103},
#  {'coadd_object_id': 1529219488, 'ra': 76.928655, 'dec': -46.928536},
#  {'coadd_object_id': 1529219566, 'ra': 76.923838, 'dec': -46.929452}]

# %%
dataframe_10_objetos = db.fetchall_df(query)
dataframe_10_objetos
# Out:
#    coadd_object_id         ra        dec
# 0       1529220421  76.914089 -46.937152
# 1       1529220121  76.918024 -46.934654
# 2       1529220129  76.914734 -46.934679
# 3       1529220385  76.912989 -46.936798
# 4       1529220066  76.911689 -46.934485
# 5       1529220084  76.923009 -46.934203
# 6       1529220030  76.923706 -46.933679
# 7       1529219643  76.925857 -46.930103
# 8       1529219488  76.928655 -46.928536
# 9       1529219566  76.923838 -46.929452

# %%
c = SkyCoord ('03h12m59.87s', '-55d07m25s', frame='icrs')
c
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (48.24945833, -55.12361111)>

# %%
print(f"R.A.: {c.ra.deg:.1f} degrees")
print(f"Dec.: {c.dec.deg:.1f} degrees")
# Out:
# R.A.: 48.2 degrees
# Dec.: -55.1 degrees

# %%
query_1 = "SELECT coadd_object_id, ra ,dec, flags_g, mag_auto_g_dered, mag_auto_r_dered, mag_auto_i_dered, magerr_auto_g, magerr_auto_r, magerr_auto_i FROM des_dr2.main WHERE q3c_poly_query(ra, dec, ARRAY[47.7, -55.6, 48.7, -55.6, 48.7, -54.6, 47.7, -54.6]) AND extended_class_coadd < 2 "        
query_1
# Out:
# 'SELECT coadd_object_id, ra ,dec, flags_g, mag_auto_g_dered, mag_auto_r_dered, mag_auto_i_dered, magerr_auto_g, magerr_auto_r, magerr_auto_i FROM des_dr2.main WHERE q3c_poly_query(ra, dec, ARRAY[47.7, -55.6, 48.7, -55.6, 48.7, -54.6, 47.7, -54.6]) AND extended_class_coadd < 2 '

# %%
# %%time
dados_exemplo_1 = db.fetchall_df(query_1)
# Out:
# CPU times: user 226 ms, sys: 50.1 ms, total: 276 ms
# Wall time: 2.2 s

# %%
dados_exemplo_1
# Out:
#        coadd_object_id         ra        dec  flags_g  mag_auto_g_dered  \
# 0           1448102086  48.576037 -55.598004        0         25.145451
# 1           1448101600  48.582090 -55.592960        0         27.381903
# 2           1448101955  48.691167 -55.597126        0         22.442909
# 3           1448102057  48.682915 -55.598155        0         24.623291
# 4           1448101710  48.696319 -55.594519        1         25.356977
# ...                ...        ...        ...      ...               ...
# 21789       1376625669  48.411527 -54.607250        0         26.905493
# 21790       1376625909  48.450046 -54.603129        0         24.707388
# 21791       1376624176  48.453170 -54.601259        0         25.131180
# 21792       1376624836  48.390221 -54.603772        0         25.609528
# 21793       1376625965  48.393719 -54.603191        0         26.091536
#
#        mag_auto_r_dered  mag_auto_i_dered  magerr_auto_g  magerr_auto_r  \
# 0             24.707537         24.299219       0.226830       0.199778
# 1             24.712021         24.716902       2.067790       0.233984
# 2             21.729532         21.496033       0.025076       0.017073
# 3             24.705683         24.427576       0.165873       0.235304
# 4             25.255629         25.157602       0.198757       0.236325
# ...                 ...               ...            ...            ...
# 21789         26.191345         24.979437       1.052494       0.741705
# 21790         24.967535         23.998575       0.272612       0.471974
# 21791         24.831013         24.055311       0.241220       0.249543
# 21792         23.549253         22.742149       0.463529       0.095034
# 21793         25.187588         26.774284       0.586795       0.347968
#
#        magerr_auto_i
# 0           0.251144
# 1           0.433203
# 2           0.025005
# 3           0.333763
# 4           0.394089
# ...              ...
# 21789       0.464212
# 21790       0.370068
# 21791       0.233529
# 21792       0.086310
# 21793       2.869226
#
# [21794 rows x 10 columns]

# %%
dados_exemplo_1.head()
# Out:
#    coadd_object_id         ra        dec  flags_g  mag_auto_g_dered  \
# 0       1448102086  48.576037 -55.598004        0         25.145451
# 1       1448101600  48.582090 -55.592960        0         27.381903
# 2       1448101955  48.691167 -55.597126        0         22.442909
# 3       1448102057  48.682915 -55.598155        0         24.623291
# 4       1448101710  48.696319 -55.594519        1         25.356977
#
#    mag_auto_r_dered  mag_auto_i_dered  magerr_auto_g  magerr_auto_r  \
# 0         24.707537         24.299219       0.226830       0.199778
# 1         24.712021         24.716902       2.067790       0.233984
# 2         21.729532         21.496033       0.025076       0.017073
# 3         24.705683         24.427576       0.165873       0.235304
# 4         25.255629         25.157602       0.198757       0.236325
#
#    magerr_auto_i
# 0       0.251144
# 1       0.433203
# 2       0.025005
# 3       0.333763
# 4       0.394089

# %%
query_2 = "SELECT coadd_object_id, ra ,dec, flags_g, mag_auto_g_dered, mag_auto_r_dered, mag_auto_i_dered, magerr_auto_g, magerr_auto_r, magerr_auto_i FROM des_dr2.main WHERE q3c_radial_query(ra, dec, 48.2, -55.1, 0.5) AND extended_class_coadd < 2 "
query_2
# Out:
# 'SELECT coadd_object_id, ra ,dec, flags_g, mag_auto_g_dered, mag_auto_r_dered, mag_auto_i_dered, magerr_auto_g, magerr_auto_r, magerr_auto_i FROM des_dr2.main WHERE q3c_radial_query(ra, dec, 48.2, -55.1, 0.5) AND extended_class_coadd < 2 '

# %%
# %%time
dados_exemplo_2 = db.fetchall_df(query_2)
# Out:
# CPU times: user 371 ms, sys: 52.6 ms, total: 423 ms
# Wall time: 986 ms

# %%
dados_exemplo_2
# Out:
#        coadd_object_id         ra        dec  flags_g  mag_auto_g_dered  \
# 0           1375822449  48.333343 -55.593565        0         24.781990
# 1           1375822631  48.318830 -55.595307        0         26.044411
# 2           1375822314  48.307078 -55.592429        0         25.283928
# 3           1375822261  48.318649 -55.591862        0         25.244452
# 4           1375821518  48.323910 -55.584959        0         25.690437
# ...                ...        ...        ...      ...               ...
# 27588       1376627561  48.450307 -54.625855        0         24.360146
# 27589       1376627359  48.442419 -54.623639        0         24.621712
# 27590       1376627051  48.435242 -54.620032        0         24.838499
# 27591       1376627029  48.429589 -54.619964        0         26.653496
# 27592       1376626673  48.416226 -54.615842        0         23.198467
#
#        mag_auto_r_dered  mag_auto_i_dered  magerr_auto_g  magerr_auto_r  \
# 0             24.139618         24.025658       0.236265       0.188936
# 1             25.997921         25.351433       0.377496       0.484635
# 2             25.220938         24.907719       0.257526       0.314850
# 3             25.488678         25.739677       0.251591       0.398529
# 4             25.131847         24.874826       0.480595       0.389419
# ...                 ...               ...            ...            ...
# 27588         24.358387         24.609964       0.088197       0.117912
# 27589         24.211773         23.820921       0.133380       0.119088
# 27590         25.180769         24.663271       0.152592       0.291979
# 27591         25.663404         25.509670       0.620004       0.340951
# 27592         23.293739         23.494356       0.043983       0.065252
#
#        magerr_auto_i
# 0           0.301119
# 1           0.481292
# 2           0.446368
# 3           0.924161
# 4           0.573758
# ...              ...
# 27588       0.288530
# 27589       0.166329
# 27590       0.346336
# 27591       0.568206
# 27592       0.151230
#
# [27593 rows x 10 columns]

# %%
dados_exemplo_2.head()
# Out:
#    coadd_object_id         ra        dec  flags_g  mag_auto_g_dered  \
# 0       1375822449  48.333343 -55.593565        0         24.781990
# 1       1375822631  48.318830 -55.595307        0         26.044411
# 2       1375822314  48.307078 -55.592429        0         25.283928
# 3       1375822261  48.318649 -55.591862        0         25.244452
# 4       1375821518  48.323910 -55.584959        0         25.690437
#
#    mag_auto_r_dered  mag_auto_i_dered  magerr_auto_g  magerr_auto_r  \
# 0         24.139618         24.025658       0.236265       0.188936
# 1         25.997921         25.351433       0.377496       0.484635
# 2         25.220938         24.907719       0.257526       0.314850
# 3         25.488678         25.739677       0.251591       0.398529
# 4         25.131847         24.874826       0.480595       0.389419
#
#    magerr_auto_i
# 0       0.301119
# 1       0.481292
# 2       0.446368
# 3       0.924161
# 4       0.573758

# %%
# %%time
plt.figure(figsize=[10,5], dpi=300)
plt.suptitle("Estrelas no DR2", fontsize=14)
plt.subplot(1,2,1)
plt.plot(dados_exemplo_1.ra, dados_exemplo_1.dec, 'k.', alpha=0.1)
plt.xlabel("R.A. (deg)", fontsize=14)
plt.ylabel("Dec. (deg)", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.subplot(1,2,2)
plt.plot(dados_exemplo_2.ra, dados_exemplo_2.dec, 'k.', alpha=0.1)
plt.xlabel("R.A. (deg)", fontsize=14)
plt.ylabel("Dec. (deg)", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
# Out:
# CPU times: user 213 ms, sys: 160 ms, total: 374 ms
# Wall time: 371 ms

# %%
# %%time
plt.figure(figsize=[12,5], dpi=300)
plt.suptitle("Estrelas no DES DR2", fontsize=14)
plt.subplot(1,2,1)
plt.hist2d(dados_exemplo_1.ra, dados_exemplo_1.dec, bins=50)
plt.xlabel("R.A. (deg)", fontsize=14)
plt.ylabel("Dec. (deg)", fontsize=14)
plt.colorbar(label="Densidade de Pontos")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.subplot(1,2,2)
plt.hist2d(dados_exemplo_2.ra, dados_exemplo_2.dec, bins=50)
plt.xlabel("R.A. (deg)", fontsize=14)
plt.ylabel("Dec. (deg)", fontsize=14)
plt.colorbar(label="Densidade de Pontos")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
# Out:
# CPU times: user 306 ms, sys: 196 ms, total: 502 ms
# Wall time: 446 ms

# %%
dados = dados_exemplo_2
del dados_exemplo_1  
del dados_exemplo_2

# %%
new_columns = {"coadd_object_id": "object_id",
               "mag_auto_g_dered": "mag_g",
               "mag_auto_r_dered": "mag_r",
               "mag_auto_i_dered": "mag_i",
               "magerr_auto_g": "err_g", 
               "magerr_auto_r": "err_r", 
               "magerr_auto_i": "err_i"}

dados.rename(columns=new_columns, inplace=True)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27593 entries, 0 to 27592
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   object_id  27593 non-null  int64
#  1   ra         27593 non-null  float64
#  2   dec        27593 non-null  float64
#  3   flags_g    27593 non-null  int64
#  4   mag_g      27593 non-null  float64
#  5   mag_r      27593 non-null  float64
#  6   mag_i      27593 non-null  float64
#  7   err_g      27593 non-null  float64
#  8   err_r      27593 non-null  float64
#  9   err_i      27593 non-null  float64
# dtypes: float64(8), int64(2)
# memory usage: 2.1 MB

# %%
dados.head()
# Out:
#     object_id         ra        dec  flags_g      mag_g      mag_r      mag_i  \
# 0  1375822449  48.333343 -55.593565        0  24.781990  24.139618  24.025658
# 1  1375822631  48.318830 -55.595307        0  26.044411  25.997921  25.351433
# 2  1375822314  48.307078 -55.592429        0  25.283928  25.220938  24.907719
# 3  1375822261  48.318649 -55.591862        0  25.244452  25.488678  25.739677
# 4  1375821518  48.323910 -55.584959        0  25.690437  25.131847  24.874826
#
#       err_g     err_r     err_i
# 0  0.236265  0.188936  0.301119
# 1  0.377496  0.484635  0.481292
# 2  0.257526  0.314850  0.446368
# 3  0.251591  0.398529  0.924161
# 4  0.480595  0.389419  0.573758

# %%
dados["gmr"] = dados.mag_g - dados.mag_r

# %%
dados.head()
# Out:
#     object_id         ra        dec  flags_g      mag_g      mag_r      mag_i  \
# 0  1375822449  48.333343 -55.593565        0  24.781990  24.139618  24.025658
# 1  1375822631  48.318830 -55.595307        0  26.044411  25.997921  25.351433
# 2  1375822314  48.307078 -55.592429        0  25.283928  25.220938  24.907719
# 3  1375822261  48.318649 -55.591862        0  25.244452  25.488678  25.739677
# 4  1375821518  48.323910 -55.584959        0  25.690437  25.131847  24.874826
#
#       err_g     err_r     err_i       gmr
# 0  0.236265  0.188936  0.301119  0.642372
# 1  0.377496  0.484635  0.481292  0.046490
# 2  0.257526  0.314850  0.446368  0.062990
# 3  0.251591  0.398529  0.924161 -0.244226
# 4  0.480595  0.389419  0.573758  0.558590

# %%
dados.query("flags_g < 4  & mag_g != 99. & mag_r != 99. & mag_i != 99. ", inplace=True)

# %%
dados.count()
# Out:
# object_id    26017
# ra           26017
# dec          26017
# flags_g      26017
# mag_g        26017
# mag_r        26017
# mag_i        26017
# err_g        26017
# err_r        26017
# err_i        26017
# gmr          26017
# dtype: int64

# %%
dados.describe()
# Out:
#           object_id            ra           dec       flags_g         mag_g  \
# count  2.601700e+04  26017.000000  26017.000000  26017.000000  26017.000000
# mean   1.387898e+09     48.168816    -55.134025      0.526118     24.358804
# std    2.575855e+07      0.392536      0.227287      1.083224      2.216128
# min    1.370218e+09     47.329687    -55.599646      0.000000     15.167205
# 25%    1.376639e+09     47.914489    -55.287064      0.000000     23.165415
# 50%    1.377062e+09     48.130568    -55.163755      0.000000     24.923405
# 75%    1.377080e+09     48.451394    -54.966675      0.000000     25.747353
# max    1.448098e+09     49.072727    -54.600796      3.000000     34.207638
#
#               mag_r         mag_i         err_g         err_r         err_i  \
# count  26017.000000  26017.000000  26017.000000  26017.000000  26017.000000
# mean      23.598145     23.299245      0.614531      0.228955      0.380075
# std        2.133830      2.248598      8.774690      1.604382      2.070695
# min       14.899950     15.440288      0.000199      0.000221      0.000243
# 25%       22.328896     21.893848      0.055081      0.033164      0.040482
# 50%       24.305340     24.029646      0.200547      0.156519      0.222317
# 75%       25.109932     24.938711      0.386362      0.269613      0.418134
# max       32.482559     31.243486    901.726074    234.452957    127.122368
#
#                 gmr
# count  26017.000000
# mean       0.760658
# std        0.763286
# min       -4.324619
# 25%        0.292749
# 50%        0.610855
# 75%        1.201235
# max        8.097160

# %%
plt.figure(figsize=[7,5])
plt.title("CMD - Estrelas no DES DR2", fontsize=14)
plt.hexbin(dados.gmr, dados.mag_r, gridsize=500, bins='log') 
plt.xlabel("$g - r$", fontsize=14)
plt.ylabel("$g$", fontsize=14)
plt.colorbar(label="Densidade de Pontos")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(-1.5,2.5)
plt.ylim(24,16)
plt.tight_layout()
